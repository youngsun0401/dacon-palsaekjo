# %% [markdown]
# 데이터에서 결측치 개수 확인

# %%
import pandas as pd

from mymodules.paths import Paths

# %%
# 결측치 확인

total_rows = 0
total_nulls = pd.Series(
    0,
    index=pd.read_csv(
            Paths('.').train_A,
            index_col='Test_id'
        ).columns,
    dtype='int64'
)# total_nulls 초기화

reader = pd.read_csv(Paths('open_v2').train_A, chunksize=10000)
for i, df in enumerate(reader):
    total_rows += len(df)
    total_nulls += df.isnull().sum()

print('총 행 수:', total_rows)
print(total_nulls)
# Out:
# 총 행 수: 647241
# Test          0.0
# PrimaryKey    0.0
# Age           0.0
# TestDate      0.0
# A1-1          0.0
# A1-2          0.0
# A1-3          0.0
# A1-4          0.0
# A2-1          1.0
# A2-2          1.0
# A2-3          1.0
# A2-4          1.0
# A3-1          1.0
# A3-2          1.0
# A3-3          1.0
# A3-4          1.0
# A3-5          1.0
# A3-6          1.0
# A3-7          1.0
# A4-1          0.0
# A4-2          0.0
# A4-3          0.0
# A4-4          0.0
# A4-5          0.0
# A5-1          2.0
# A5-2          2.0
# A5-3          2.0
# A6-1          0.0
# A7-1          0.0
# A8-1          0.0
# A8-2          0.0
# A9-1          0.0
# A9-2          0.0
# A9-3          0.0
# A9-4          0.0
# A9-5          0.0
# dtype: float64

# %%
# 결측치 확인

total_rows = 0
total_nulls = pd.Series(
    0,
    index=pd.read_csv(
            Paths('.').train_B
        ).columns,
    dtype='int64'
)# total_nulls 초기화

reader = pd.read_csv(Paths('open_v2').train_B, chunksize=10000)
for i, df in enumerate(reader):
    total_rows += len(df)
    total_nulls += df.isnull().sum()

print('총 행 수:', total_rows)
print(total_nulls)
# Out:
# 총 행 수: 297526
# Test_id       0
# Test          0
# PrimaryKey    0
# Age           0
# TestDate      0
# B1-1          9
# B1-2          9
# B1-3          9
# B2-1          3
# B2-2          3
# B2-3          3
# B3-1          3
# B3-2          3
# B4-1          3
# B4-2          3
# B5-1          3
# B5-2          3
# B6            3
# B7            2
# B8            1
# B9-1          0
# B9-2          0
# B9-3          0
# B9-4          0
# B9-5          0
# B10-1         0
# B10-2         0
# B10-3         0
# B10-4         0
# B10-5         0
# B10-6         0
# dtype: int64
