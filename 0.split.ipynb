# %% [markdown]
# 전체 데이터를 학습용/테스트용 나눠야지.

# %%
import os
import pandas as pd

from mymodules.wkqehdtksl import Paths

# %%
PATH = Paths('open_v2')
CHUNK_SIZE = 10000
FILE_PATH_0 = PATH.aggt_A
FILE_PATH_1 = PATH.aggt_A + '-train'
FILE_PATH_2 = PATH.aggt_A + '-test'

# %%
if os.path.exists(FILE_PATH_1):
    os.remove(FILE_PATH_1)
if os.path.exists(FILE_PATH_2):
    os.remove(FILE_PATH_2)

# %%
reader = pd.read_csv(FILE_PATH_0, index_col='Test_id', chunksize=CHUNK_SIZE)
for i, chunk in enumerate(reader):
    part1 = 
    part2 = 
    # 3:1 비율로 나눠서 저장
    part1.to_csv(FILE_PATH_1, mode='a', index='Test_id', header=(i == 0))
    part2.to_csv(FILE_PATH_2, mode='a', index='Test_id', header=(i == 0))
